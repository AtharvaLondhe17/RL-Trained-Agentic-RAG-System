# %% [markdown]
# # RL Agentic RAG — Evaluation Notebook
#
# This notebook evaluates the RAG system's performance.

# %%
import httpx
import json

BASE_URL = "http://localhost:8000"

# Health check
r = httpx.get(f"{BASE_URL}/health")
print(r.json())

# %%
# Sample query
r = httpx.post(f"{BASE_URL}/query", json={"query": "What is RAG?", "session_id": "eval"})
result = r.json()
print(json.dumps(result, indent=2))
